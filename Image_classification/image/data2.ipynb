# %%
import torch
import torchvision
from torchvision import transforms # 이미지 데이터 transform
from torch.utils.data import DataLoader # 이미지 데이터 로더
import os
import glob

# %%
train_path = '/mnt/c/Users/hajun/Project/image/train'
test_path = '/mnt/c/Users/hajun/Project/image/test'

IU_dir = '/IU/'
Seulgi_dir = '/Seulgi/'
Son_dir = '/Son/'

# %%
resize_trans = transforms.Compose([
                                   transforms.Resize((128,128)),
                                   transforms.ToTensor()
])

resize_train = torchvision.datasets.ImageFolder(root=train_path, transform=resize_trans)
resize_test = torchvision.datasets.ImageFolder(root=test_path, transform=resize_trans)

# %%
resize_train[0][0].shape
# Out:
# torch.Size([3, 128, 128])

# %%
resize_train[0][0]
# Out:
# tensor([[[0.8353, 0.8353, 0.8353,  ..., 0.4118, 0.4118, 0.4078],
#          [0.8353, 0.8353, 0.8353,  ..., 0.4196, 0.4196, 0.4078],
#          [0.8392, 0.8392, 0.8353,  ..., 0.4196, 0.4196, 0.4118],
#          ...,
#          [0.6078, 0.2196, 0.1216,  ..., 0.8039, 0.5333, 0.5647],
#          [0.7333, 0.3333, 0.1255,  ..., 0.8039, 0.6235, 0.6549],
#          [0.7412, 0.4157, 0.1333,  ..., 0.8510, 0.8196, 0.7765]],
#
#         [[0.9176, 0.9176, 0.9176,  ..., 0.4824, 0.4824, 0.4863],
#          [0.9176, 0.9176, 0.9176,  ..., 0.4902, 0.4902, 0.4863],
#          [0.9176, 0.9176, 0.9137,  ..., 0.4902, 0.4902, 0.4902],
#          ...,
#          [0.5922, 0.2118, 0.1255,  ..., 0.7569, 0.5137, 0.5529],
#          [0.7098, 0.3216, 0.1294,  ..., 0.7490, 0.5882, 0.6118],
#          [0.6980, 0.3922, 0.1373,  ..., 0.7843, 0.7608, 0.7294]],
#
#         [[0.9333, 0.9333, 0.9333,  ..., 0.4353, 0.4353, 0.4431],
#          [0.9412, 0.9412, 0.9373,  ..., 0.4431, 0.4431, 0.4431],
#          [0.9490, 0.9490, 0.9451,  ..., 0.4431, 0.4431, 0.4471],
#          ...,
#          [0.5804, 0.2196, 0.1529,  ..., 0.7412, 0.5176, 0.5569],
#          [0.6980, 0.3216, 0.1529,  ..., 0.7255, 0.5765, 0.5882],
#          [0.6941, 0.3922, 0.1569,  ..., 0.7686, 0.7294, 0.7020]]])

# %%
import numpy as np
np.mean(resize_train[0][0].numpy(),axis=(1,2)) # numpy로 바꾸고, axis = 1,2 mean으로 RGB mean/std 뽑기
# Out:
# array([0.5568108 , 0.57602346, 0.60199404], dtype=float32)

# %%
def get_mean_std(dataset):
  meanRGB = [np.mean(image.numpy(), axis=(1,2)) for image,_ in dataset]
  stdRGB = [np.std(image.numpy(), axis=(1,2)) for image,_ in dataset]

  meanR = np.mean([m[0] for m in meanRGB])
  meanG = np.mean([m[1] for m in meanRGB])
  meanB = np.mean([m[2] for m in meanRGB])

  stdR = np.mean([s[0] for s in stdRGB])
  stdG = np.mean([s[1] for s in stdRGB])
  stdB = np.mean([s[2] for s in stdRGB])

  print(meanR, meanG, meanB)
  print(stdR, stdG, stdB)

# %%
resize_train_mean=[0.17191947, 0.41128376, 0.56153077]
resize_train_std=[0.16150557, 0.16577946, 0.16063999]

resize_test_mean=[0.15918699, 0.410329, 0.55247366]
resize_test_std=[0.1542138, 0.16098696, 0.15552239]

# %%
transform_train = transforms.Compose([
    transforms.Resize((128, 128)), # 이미지 resize
    transforms.RandomCrop(124), # 이미지를 랜덤으로 크롭
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2), # 이미지 지터링(밝기, 대조, 채비, 색조)
    transforms.RandomHorizontalFlip(p = 1), # p확률로 이미지 좌우반전
    transforms.RandomVerticalFlip(p = 1), # p확률로 상하반전
    transforms.ToTensor(),
    transforms.Normalize(resize_train_mean, resize_train_std)
])

transform_test = transforms.Compose([
    transforms.Resize((128, 128)), 
    transforms.ToTensor(),
    transforms.Normalize(resize_test_mean, resize_test_std)
])

trainset = torchvision.datasets.ImageFolder(root=train_path, transform=transform_train)
testset = torchvision.datasets.ImageFolder(root=test_path, transform=transform_test)

train_loader = torch.utils.data.DataLoader(trainset, batch_size=1,
                                          shuffle=True, num_workers=0)

test_loader = torch.utils.data.DataLoader(testset, batch_size=1,
                                         shuffle=False, num_workers=0)

# %%
images, labels = next(iter(train_loader))
images.shape
# Out:
# torch.Size([1, 3, 124, 124])

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

def imshow(img, mean, std):
    npimg = img.numpy()
    img = np.transpose( npimg, (1, 2, 0) )
    img = img * std + mean # renormalize
    img = img.clip(0, 1)
    plt.imshow(img)
    plt.show()


none_trans = torchvision.datasets.ImageFolder(root=train_path, transform=None)

# %%
none_trans[200][0]
# Out:
# <PIL.Image.Image image mode=RGB size=500x500>

# %%
# 경로 지정

train_path = '/mnt/c/Users/hajun/Project/image/train'
test_path = '/mnt/c/Users/hajun/Project/image/test'

Dataset_path = '/mnt/c/Users/hajun/Project/image'

IU_dir = '/IU/'
Seulgi_dir = '/Seulgi/'
Son_dir = '/Son/'

# %%
from torch.utils.data import Dataset, DataLoader # 데이터 커스터마이징
from PIL import Image # PIL = Python Image Library
import cv2 # albumentation transform을 쓰려면 꼭 이 라이브러리를 이용
import tensorflow as tf

class inhovation_Dataset(Dataset):

  def __init__(self, file_path, mode, transform=None):
    self.all_data = sorted(glob.glob(os.path.join(file_path, mode, '*', '*')))
    self.transform = transform

  def __getitem__(self, index):

    if torch.is_tensor(index):        # 인덱스가 tensor 형태일 수 있으니 리스트 형태로 바꿔준다.
       index = index.tolist()

    data_path = self.all_data[index]
    #img = np.array(Image.open(data_path).convert("RGB")) # albumenatation transform을 쓰려면 cv2 라이브러리로 이미지를 읽어야 함
    image=cv2.imread(data_path)
    image=cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # BGR -> RGB 변환

    # transform 적용
    if self.transform is not None:    
       augmented = self.transform(image)
       image = augmented['image'] 

    # 이미지 이름을 활용해 label 부여
    label=[]                                
    if os.path.basename(data_path).startswith("IU") == True:
        label = 0
    elif os.path.basename(data_path).startswith("Seulgi") == True: 
        label = 1
    elif os.path.basename(data_path).startswith("Son") == True:
        label = 2
    return image, label

  def __len__(self):
    length = len(self.all_data)
    return length

# %%
Image.open(inhovation_Dataset(Dataset_path,'train', transform = transform_train).all_data[105])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x500>

# %%
import albumentations
from albumentations.pytorch import ToTensorV2

albumentations_resize = albumentations.Compose([
    albumentations.Resize(128, 128),
    ToTensorV2()
])

resize_train = inhovation_Dataset(Dataset_path, 'train', transform=albumentations_resize)
resize_test = inhovation_Dataset(Dataset_path, 'test', transform=albumentations_resize)

# %%
def tensor_img(img):    
    img = img.permute(1,2,0)
    plt.imshow(img)

# %%
import albumentations
from torchvision import transforms # 이미지 데이터 transform
from torch.utils.data import DataLoader # 이미지 데이터 로더
from albumentations.pytorch import ToTensorV2

albumentations_train = albumentations.Compose([
                                                
    albumentations.Resize(128, 128),   
    albumentations.OneOf([
                          albumentations.HorizontalFlip(p=0.8), # p확률로 이미지 좌우 반전
                          albumentations.RandomRotate90(p=0.8), # p확률로 90도 회전
                          albumentations.VerticalFlip(p=0.8) # p확률로 이미지 상하 반전
    ], p=1),

    albumentations.OneOf([
                          albumentations.MotionBlur(p=0.8), # p확률로 이미지를 흐리게(?) 만들어 줌
                          albumentations.OpticalDistortion(p=0.8), # p확률로 이미지 왜곡
                          albumentations.GaussNoise(p=0.8) # 임의의 noise를 삽입          
    ], p=1),
    # albumentations.Normalize(mean = resize_train_mean, std = resize_train_std),
    ToTensorV2()
    
])

albumentations_test = albumentations.Compose([
                                                
    albumentations.Resize(128, 128),
    ToTensorV2()
    
])


trainset=inhovation_Dataset(Dataset_path, 'train', transform=albumentations_train)
testset=inhovation_Dataset(Dataset_path, 'test', transform=albumentations_test)

train_loader = torch.utils.data.DataLoader(trainset, batch_size=1,
                                          shuffle=True, num_workers=0)

test_loader = torch.utils.data.DataLoader(testset, batch_size=1,
                                         shuffle=False, num_workers=0)

# %% [markdown]
# resnet 50 아키텍쳐 구성

# %%
# import resnet
import torchvision.models.resnet as resnet
import torch.nn as nn
import torch.optim as optim

# 미리 정의
conv1x1=resnet.conv1x1
Bottleneck = resnet.Bottleneck
BasicBlock= resnet.BasicBlock

# %%
class ResNet(nn.Module):

    def __init__(self, block, layers, num_classes=1000, zero_init_residual=True):
        super(ResNet, self).__init__()
        self.inplanes = 32 # conv1에서 나올 채널의 차원 -> 이미지넷보다 작은 데이터이므로 32로 조정

        # inputs = 3x224x224 -> 3x128x128로 바뀜
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1, bias=False) # 마찬가지로 전부 사이즈 조정
        self.bn1 = nn.BatchNorm2d(32)
        self.relu = nn.ReLU(inplace=True)
        self.maxpool = nn.MaxPool2d(kernel_size=3, stride=2, padding=1)
        
        self.layer1 = self._make_layer(block, 32, layers[0], stride=1) # 3 반복
        self.layer2 = self._make_layer(block, 64, layers[1], stride=2) # 4 반복
        self.layer3 = self._make_layer(block, 128, layers[2], stride=2) # 6 반복
        self.layer4 = self._make_layer(block, 256, layers[3], stride=2) # 3 반복
        
        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        self.fc = nn.Linear(256 * block.expansion, num_classes)

        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
            elif isinstance(m, nn.BatchNorm2d):
                nn.init.constant_(m.weight, 1)
                nn.init.constant_(m.bias, 0)

        # Zero-initialize the last BN in each residual branch,
        # so that the residual branch starts with zeros, and each residual block behaves like an identity.
        # This improves the model by 0.2~0.3% according to https://arxiv.org/abs/1706.02677
        if zero_init_residual:
            for m in self.modules():
                if isinstance(m, Bottleneck):
                    nn.init.constant_(m.bn3.weight, 0)
                elif isinstance(m, BasicBlock):
                    nn.init.constant_(m.bn2.weight, 0)

    def _make_layer(self, block, planes, blocks, stride=1): # planes -> 입력되는 채널 수
        downsample = None
        if stride != 1 or self.inplanes != planes * block.expansion: 
            downsample = nn.Sequential(
                conv1x1(self.inplanes, planes * block.expansion, stride),
                nn.BatchNorm2d(planes * block.expansion),
            )

        layers = []
        layers.append(block(self.inplanes, planes, stride, downsample))
        self.inplanes = planes * block.expansion
        for _ in range(1, blocks):
            layers.append(block(self.inplanes, planes))

        return nn.Sequential(*layers)

    def forward(self, x):
        # input [32, 128, 128] -> [C ,H, W]
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.relu(x)
        x = self.maxpool(x)
        #x.shape =[32, 64, 64]

        x = self.layer1(x)
        #x.shape =[128, 64, 64]
        x = self.layer2(x)
        #x.shape =[256, 32, 32]
        x = self.layer3(x)
        #x.shape =[512, 16, 16]
        x = self.layer4(x)
        #x.shape =[1024, 8, 8]
        
        x = self.avgpool(x)
        x = x.view(x.size(0), -1)
        x = self.fc(x)

        return x

# %%
import torch

# GPU가 사용 가능한 경우 'cuda:0', 그렇지 않은 경우 'cpu'를 사용
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

resnet50 = ResNet(resnet.Bottleneck, [3, 4, 6, 3], 3, True).to(device)

# %%
from torchsummary import summary

# device가 'cuda' 또는 'cpu'인 문자열로 변환
device_str = "cuda" if device.type == "cuda" else "cpu"

# 문자열 device를 summary 함수에 전달
summary(resnet50, input_size=(3, 128, 128), device=device_str)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 32, 128, 128]             864
#        BatchNorm2d-2         [-1, 32, 128, 128]              64
#               ReLU-3         [-1, 32, 128, 128]               0
#          MaxPool2d-4           [-1, 32, 64, 64]               0
#             Conv2d-5           [-1, 32, 64, 64]           1,024
#        BatchNorm2d-6           [-1, 32, 64, 64]              64
#               ReLU-7           [-1, 32, 64, 64]               0
#             Conv2d-8           [-1, 32, 64, 64]           9,216
#        BatchNorm2d-9           [-1, 32, 64, 64]              64
#              ReLU-10           [-1, 32, 64, 64]               0
#            Conv2d-11          [-1, 128, 64, 64]           4,096
#       BatchNorm2d-12          [-1, 128, 64, 64]             256
#            Conv2d-13          [-1, 128, 64, 64]           4,096
#       BatchNorm2d-14          [-1, 128, 64, 64]             256
#              ReLU-15          [-1, 128, 64, 64]               0
#        Bottleneck-16          [-1, 128, 64, 64]               0
#            Conv2d-17           [-1, 32, 64, 64]           4,096
#       BatchNorm2d-18           [-1, 32, 64, 64]              64
#              ReLU-19           [-1, 32, 64, 64]               0
#            Conv2d-20           [-1, 32, 64, 64]           9,216
#       BatchNorm2d-21           [-1, 32, 64, 64]              64
#              ReLU-22           [-1, 32, 64, 64]               0
#            Conv2d-23          [-1, 128, 64, 64]           4,096
#       BatchNorm2d-24          [-1, 128, 64, 64]             256
#              ReLU-25          [-1, 128, 64, 64]               0
#        Bottleneck-26          [-1, 128, 64, 64]               0
#            Conv2d-27           [-1, 32, 64, 64]           4,096
#       BatchNorm2d-28           [-1, 32, 64, 64]              64
#              ReLU-29           [-1, 32, 64, 64]               0
#            Conv2d-30           [-1, 32, 64, 64]           9,216
#       BatchNorm2d-31           [-1, 32, 64, 64]              64
#              ReLU-32           [-1, 32, 64, 64]               0
#            Conv2d-33          [-1, 128, 64, 64]           4,096
#       BatchNorm2d-34          [-1, 128, 64, 64]             256
#              ReLU-35          [-1, 128, 64, 64]               0
#        Bottleneck-36          [-1, 128, 64, 64]               0
#            Conv2d-37           [-1, 64, 64, 64]           8,192
#       BatchNorm2d-38           [-1, 64, 64, 64]             128
#              ReLU-39           [-1, 64, 64, 64]               0
#            Conv2d-40           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-41           [-1, 64, 32, 32]             128
#              ReLU-42           [-1, 64, 32, 32]               0
#            Conv2d-43          [-1, 256, 32, 32]          16,384
#       BatchNorm2d-44          [-1, 256, 32, 32]             512
#            Conv2d-45          [-1, 256, 32, 32]          32,768
#       BatchNorm2d-46          [-1, 256, 32, 32]             512
#              ReLU-47          [-1, 256, 32, 32]               0
#        Bottleneck-48          [-1, 256, 32, 32]               0
#            Conv2d-49           [-1, 64, 32, 32]          16,384
#       BatchNorm2d-50           [-1, 64, 32, 32]             128
#              ReLU-51           [-1, 64, 32, 32]               0
#            Conv2d-52           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-53           [-1, 64, 32, 32]             128
#              ReLU-54           [-1, 64, 32, 32]               0
#            Conv2d-55          [-1, 256, 32, 32]          16,384
#       BatchNorm2d-56          [-1, 256, 32, 32]             512
#              ReLU-57          [-1, 256, 32, 32]               0
#        Bottleneck-58          [-1, 256, 32, 32]               0
#            Conv2d-59           [-1, 64, 32, 32]          16,384
#       BatchNorm2d-60           [-1, 64, 32, 32]             128
#              ReLU-61           [-1, 64, 32, 32]               0
#            Conv2d-62           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-63           [-1, 64, 32, 32]             128
#              ReLU-64           [-1, 64, 32, 32]               0
#            Conv2d-65          [-1, 256, 32, 32]          16,384
#       BatchNorm2d-66          [-1, 256, 32, 32]             512
#              ReLU-67          [-1, 256, 32, 32]               0
#        Bottleneck-68          [-1, 256, 32, 32]               0
#            Conv2d-69           [-1, 64, 32, 32]          16,384
#       BatchNorm2d-70           [-1, 64, 32, 32]             128
#              ReLU-71           [-1, 64, 32, 32]               0
#            Conv2d-72           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-73           [-1, 64, 32, 32]             128
#              ReLU-74           [-1, 64, 32, 32]               0
#            Conv2d-75          [-1, 256, 32, 32]          16,384
#       BatchNorm2d-76          [-1, 256, 32, 32]             512
#              ReLU-77          [-1, 256, 32, 32]               0
#        Bottleneck-78          [-1, 256, 32, 32]               0
#            Conv2d-79          [-1, 128, 32, 32]          32,768
#       BatchNorm2d-80          [-1, 128, 32, 32]             256
#              ReLU-81          [-1, 128, 32, 32]               0
#            Conv2d-82          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-83          [-1, 128, 16, 16]             256
#              ReLU-84          [-1, 128, 16, 16]               0
#            Conv2d-85          [-1, 512, 16, 16]          65,536
#       BatchNorm2d-86          [-1, 512, 16, 16]           1,024
#            Conv2d-87          [-1, 512, 16, 16]         131,072
#       BatchNorm2d-88          [-1, 512, 16, 16]           1,024
#              ReLU-89          [-1, 512, 16, 16]               0
#        Bottleneck-90          [-1, 512, 16, 16]               0
#            Conv2d-91          [-1, 128, 16, 16]          65,536
#       BatchNorm2d-92          [-1, 128, 16, 16]             256
#              ReLU-93          [-1, 128, 16, 16]               0
#            Conv2d-94          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-95          [-1, 128, 16, 16]             256
#              ReLU-96          [-1, 128, 16, 16]               0
#            Conv2d-97          [-1, 512, 16, 16]          65,536
#       BatchNorm2d-98          [-1, 512, 16, 16]           1,024
#              ReLU-99          [-1, 512, 16, 16]               0
#       Bottleneck-100          [-1, 512, 16, 16]               0
#           Conv2d-101          [-1, 128, 16, 16]          65,536
#      BatchNorm2d-102          [-1, 128, 16, 16]             256
#             ReLU-103          [-1, 128, 16, 16]               0
#           Conv2d-104          [-1, 128, 16, 16]         147,456
#      BatchNorm2d-105          [-1, 128, 16, 16]             256
#             ReLU-106          [-1, 128, 16, 16]               0
#           Conv2d-107          [-1, 512, 16, 16]          65,536
#      BatchNorm2d-108          [-1, 512, 16, 16]           1,024
#             ReLU-109          [-1, 512, 16, 16]               0
#       Bottleneck-110          [-1, 512, 16, 16]               0
#           Conv2d-111          [-1, 128, 16, 16]          65,536
#      BatchNorm2d-112          [-1, 128, 16, 16]             256
#             ReLU-113          [-1, 128, 16, 16]               0
#           Conv2d-114          [-1, 128, 16, 16]         147,456
#      BatchNorm2d-115          [-1, 128, 16, 16]             256
#             ReLU-116          [-1, 128, 16, 16]               0
#           Conv2d-117          [-1, 512, 16, 16]          65,536
#      BatchNorm2d-118          [-1, 512, 16, 16]           1,024
#             ReLU-119          [-1, 512, 16, 16]               0
#       Bottleneck-120          [-1, 512, 16, 16]               0
#           Conv2d-121          [-1, 128, 16, 16]          65,536
#      BatchNorm2d-122          [-1, 128, 16, 16]             256
#             ReLU-123          [-1, 128, 16, 16]               0
#           Conv2d-124          [-1, 128, 16, 16]         147,456
#      BatchNorm2d-125          [-1, 128, 16, 16]             256
#             ReLU-126          [-1, 128, 16, 16]               0
#           Conv2d-127          [-1, 512, 16, 16]          65,536
#      BatchNorm2d-128          [-1, 512, 16, 16]           1,024
#             ReLU-129          [-1, 512, 16, 16]               0
#       Bottleneck-130          [-1, 512, 16, 16]               0
#           Conv2d-131          [-1, 128, 16, 16]          65,536
#      BatchNorm2d-132          [-1, 128, 16, 16]             256
#             ReLU-133          [-1, 128, 16, 16]               0
#           Conv2d-134          [-1, 128, 16, 16]         147,456
#      BatchNorm2d-135          [-1, 128, 16, 16]             256
#             ReLU-136          [-1, 128, 16, 16]               0
#           Conv2d-137          [-1, 512, 16, 16]          65,536
#      BatchNorm2d-138          [-1, 512, 16, 16]           1,024
#             ReLU-139          [-1, 512, 16, 16]               0
#       Bottleneck-140          [-1, 512, 16, 16]               0
#           Conv2d-141          [-1, 256, 16, 16]         131,072
#      BatchNorm2d-142          [-1, 256, 16, 16]             512
#             ReLU-143          [-1, 256, 16, 16]               0
#           Conv2d-144            [-1, 256, 8, 8]         589,824
#      BatchNorm2d-145            [-1, 256, 8, 8]             512
#             ReLU-146            [-1, 256, 8, 8]               0
#           Conv2d-147           [-1, 1024, 8, 8]         262,144
#      BatchNorm2d-148           [-1, 1024, 8, 8]           2,048
#           Conv2d-149           [-1, 1024, 8, 8]         524,288
#      BatchNorm2d-150           [-1, 1024, 8, 8]           2,048
#             ReLU-151           [-1, 1024, 8, 8]               0
#       Bottleneck-152           [-1, 1024, 8, 8]               0
#           Conv2d-153            [-1, 256, 8, 8]         262,144
#      BatchNorm2d-154            [-1, 256, 8, 8]             512
#             ReLU-155            [-1, 256, 8, 8]               0
#           Conv2d-156            [-1, 256, 8, 8]         589,824
#      BatchNorm2d-157            [-1, 256, 8, 8]             512
#             ReLU-158            [-1, 256, 8, 8]               0
#           Conv2d-159           [-1, 1024, 8, 8]         262,144
#      BatchNorm2d-160           [-1, 1024, 8, 8]           2,048
#             ReLU-161           [-1, 1024, 8, 8]               0
#       Bottleneck-162           [-1, 1024, 8, 8]               0
#           Conv2d-163            [-1, 256, 8, 8]         262,144
#      BatchNorm2d-164            [-1, 256, 8, 8]             512
#             ReLU-165            [-1, 256, 8, 8]               0
#           Conv2d-166            [-1, 256, 8, 8]         589,824
#      BatchNorm2d-167            [-1, 256, 8, 8]             512
#             ReLU-168            [-1, 256, 8, 8]               0
#           Conv2d-169           [-1, 1024, 8, 8]         262,144
#      BatchNorm2d-170           [-1, 1024, 8, 8]           2,048
#             ReLU-171           [-1, 1024, 8, 8]               0
#       Bottleneck-172           [-1, 1024, 8, 8]               0
# AdaptiveAvgPool2d-173           [-1, 1024, 1, 1]               0
#           Linear-174                    [-1, 3]           3,075
# ================================================================
# Total params: 5,891,875
# Trainable params: 5,891,875
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.19
# Forward/backward pass size (MB): 187.13
# Params size (MB): 22.48
# Estimated Total Size (MB): 209.80
# ----------------------------------------------------------------

# %%
# config 모델 파라미터 인자를 만들기위한 클래스
class Config:
  def __init__(self, **kwargs):
    for key, value in kwargs.items():
      setattr(self, key, value)

# %%
lr = 0.0008
epochs = 30
optimizer = 'Adam'

# %%
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

# 데이터 변환 정의
transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
])

# 학습용 데이터셋 로드
train_dataset = datasets.ImageFolder(root='/mnt/c/Users/hajun/Project/image/train', transform=transform)

# DataLoader 설정
trainloader = DataLoader(dataset=train_dataset, batch_size=64, shuffle=True)

# 테스트용 데이터셋과 DataLoader도 비슷한 방식으로 설정할 수 있습니다.
test_dataset = datasets.ImageFolder(root='/mnt/c/Users/hajun/Project/image/test', transform=transform)
testloader = DataLoader(dataset=test_dataset, batch_size=64, shuffle=False)


# 파라미터 클래스
config = Config(
    trainloader = trainloader,
    testloader = testloader,
    model = resnet50,
    device = device,
    optimizer = torch.optim.Adam(resnet50.parameters(), lr=lr),
    criterion= nn.CrossEntropyLoss().to(device),
    globaliter = 0
)

# %%
class train_test():
      def __init__(self, config):
        # 파라미터 인자
        self.trainloader = config.trainloader
        self.testloader = config.testloader
        self.model = config.model
        self.device = config.device
        self.optimizer = config.optimizer
        self.criterion = config.criterion
        self.globaliter = config.globaliter
        print(len(trainloader))
      def train(self, epochs, log_interval):
          self.model.train()
          for epoch in range(1, epochs + 1 ):  # epochs 루프
              running_loss = 0.0
              lr_sche.step()
              for i, data in enumerate(self.trainloader, 0): # batch 루프
                  # get the inputs
                  self.globaliter += 1
                  inputs, labels = data # input data, label 분리
                  inputs = inputs.to(self.device)
                  labels = labels.to(self.device)

                  # 가중치 초기화 -> 이전 batch에서 계산되었던 가중치를 0으로 만들고 최적화 진행
                  self.optimizer.zero_grad() 

                  # forward + backward + optimize
                  outputs = self.model(inputs)
                  loss = self.criterion(outputs, labels)
                  loss.backward()
                  self.optimizer.step()
                  running_loss += loss.item()

                  # 30 iteration마다 acc & loss 출력
                  if i % log_interval == log_interval -1 : # i는 1에포크의 iteration
                    print('Train Epoch: {} [{}/{} ({:.0f}%)]\tlearningLoss: {:.6f}\twhole_loss: {:.6f} '.format(
                        epoch, i*len(inputs), len(self.trainloader.dataset),
                        100. * i*len(inputs) / len(self.trainloader.dataset), 
                        running_loss / log_interval,
                        loss.item()))
                    running_loss = 0.0

                    #with train_summary_writer.as_default():
                    #    summary.scalar('loss', loss.item() , step = self.globaliter)

              with torch.no_grad():
                  self.model.eval()
                  correct = 0
                  total = 0
                  test_loss = 0
                  acc = []
                  for k, data in enumerate(self.testloader, 0):
                    images, labels = data
                    images = images.to(self.device)
                    labels = labels.to(self.device)
                    outputs = self.model(images)

                    _, predicted = torch.max(outputs.data, 1)
                    total += labels.size(0)
                    correct += (predicted == labels).sum().item()
                    test_loss += self.criterion(outputs, labels).item()
                    acc.append(100 * correct/total)

                  print('\nTest set : Average loss:{:.4f}, Accuracy: {}/{}({:.0f}%)\n'.format(
                      test_loss, correct, total, 100 * correct/total
                  ))
                  #with test_summary_writer.as_default():
                  #    summary.scalar('loss', test_loss , step = self.globaliter)
                  #    summary.scalar('accuracy', 100 * correct/total , step = self.globaliter)  
##                      if acc [k] > 60 and acc[k] > acc[k-1]:
#                         torch.save({
#                                     'epoch': epoch,
#                                     'model_state_dict': self.model.state_dict(),
#                                     'optimizer_state_dict': self.optimizer.state_dict(),
#                                     'loss': test_loss
#                                     }, PATH)
                         
      print('Finished Training')
# Out:
# Finished Training

# %%
ready_to_train=train_test(config)
# Out:
# 4

# %%
lr_sche = optim.lr_scheduler.StepLR(config.optimizer, step_size=10000, gamma=0.5) # 20 step마다 lr조정
epochs = 200
log_interval = 175

ready_to_train.train(epochs, log_interval)
# Out:
# /home/hajun/anaconda3/envs/image/lib/python3.12/site-packages/torch/optim/lr_scheduler.py:143: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# Test set : Average loss:1.0949, Accuracy: 20/60(33%)
#
#
# Test set : Average loss:1.0847, Accuracy: 25/60(42%)
#
#
# Test set : Average loss:1.0691, Accuracy: 25/60(42%)
#
#
# Test set : Average loss:1.0939, Accuracy: 27/60(45%)
#
#
# Test set : Average loss:1.0603, Accuracy: 29/60(48%)
#
#
# Test set : Average loss:1.1214, Accuracy: 28/60(47%)
#
#
# Test set : Average loss:1.1425, Accuracy: 25/60(42%)
#
#
# Test set : Average loss:1.1592, Accuracy: 30/60(50%)
#
#
# Test set : Average loss:1.1069, Accuracy: 29/60(48%)
#
#
# Test set : Average loss:1.0896, Accuracy: 29/60(48%)
#
#
# Test set : Average loss:1.1318, Accuracy: 28/60(47%)
#
#
# Test set : Average loss:1.0674, Accuracy: 29/60(48%)
#
#
# Test set : Average loss:1.0811, Accuracy: 35/60(58%)
#
#
# Test set : Average loss:1.0796, Accuracy: 37/60(62%)
#
#
# Test set : Average loss:1.0040, Accuracy: 30/60(50%)
#
#
# Test set : Average loss:1.0616, Accuracy: 30/60(50%)
#
#
# Test set : Average loss:0.9487, Accuracy: 29/60(48%)
#
#
# Test set : Average loss:1.0224, Accuracy: 37/60(62%)
#
#
# Test set : Average loss:0.9472, Accuracy: 35/60(58%)
#
#
# Test set : Average loss:0.9634, Accuracy: 36/60(60%)
#
#
# Test set : Average loss:0.9287, Accuracy: 34/60(57%)
#
#
# Test set : Average loss:0.9979, Accuracy: 39/60(65%)
#
#
# Test set : Average loss:0.8035, Accuracy: 34/60(57%)
#
#
# Test set : Average loss:0.8334, Accuracy: 39/60(65%)
#
#
# Test set : Average loss:0.7443, Accuracy: 41/60(68%)
#
#
# Test set : Average loss:0.7486, Accuracy: 42/60(70%)
#
#
# Test set : Average loss:1.0062, Accuracy: 31/60(52%)
#
#
# Test set : Average loss:0.7274, Accuracy: 39/60(65%)
#
#
# Test set : Average loss:0.7208, Accuracy: 45/60(75%)
#
#
# Test set : Average loss:0.9656, Accuracy: 37/60(62%)
#
#
# Test set : Average loss:0.7295, Accuracy: 39/60(65%)
#
#
# Test set : Average loss:0.7686, Accuracy: 38/60(63%)
#
#
# Test set : Average loss:1.0390, Accuracy: 31/60(52%)
#
#
# Test set : Average loss:0.6772, Accuracy: 44/60(73%)
#
#
# Test set : Average loss:0.7338, Accuracy: 39/60(65%)
#
#
# Test set : Average loss:0.8622, Accuracy: 34/60(57%)
#
#
# Test set : Average loss:0.7707, Accuracy: 40/60(67%)
#
#
# Test set : Average loss:0.7072, Accuracy: 46/60(77%)
#
#
# Test set : Average loss:0.9511, Accuracy: 35/60(58%)
#
#
# Test set : Average loss:0.7152, Accuracy: 44/60(73%)
#
#
# Test set : Average loss:0.7473, Accuracy: 43/60(72%)
#
#
# Test set : Average loss:0.9935, Accuracy: 37/60(62%)
#
#
# Test set : Average loss:1.0332, Accuracy: 39/60(65%)
#
#
# Test set : Average loss:0.9572, Accuracy: 45/60(75%)
#
#
# Test set : Average loss:0.9482, Accuracy: 42/60(70%)
#
#
# Test set : Average loss:0.8336, Accuracy: 33/60(55%)
#
#
# Test set : Average loss:0.6486, Accuracy: 45/60(75%)
#
#
# Test set : Average loss:0.7678, Accuracy: 43/60(72%)
#
#
# Test set : Average loss:0.7451, Accuracy: 44/60(73%)
#
#
# Test set : Average loss:0.7788, Accuracy: 40/60(67%)
#
#
# Test set : Average loss:0.7072, Accuracy: 44/60(73%)
#
#
# Test set : Average loss:0.6844, Accuracy: 45/60(75%)
#
#
# Test set : Average loss:0.7533, Accuracy: 44/60(73%)
#
#
# Test set : Average loss:0.7027, Accuracy: 45/60(75%)
#
#
# Test set : Average loss:0.7512, Accuracy: 43/60(72%)
#
#
# Test set : Average loss:1.0729, Accuracy: 40/60(67%)
#
#
# Test set : Average loss:0.8258, Accuracy: 45/60(75%)
#
#
# Test set : Average loss:0.8969, Accuracy: 45/60(75%)
#
#
# Test set : Average loss:0.7803, Accuracy: 45/60(75%)
#
#
# Test set : Average loss:0.9929, Accuracy: 46/60(77%)
#
#
# Test set : Average loss:1.3746, Accuracy: 36/60(60%)
#
#
# Test set : Average loss:0.7444, Accuracy: 47/60(78%)
#
#
# Test set : Average loss:0.8773, Accuracy: 44/60(73%)
#
#
# Test set : Average loss:1.0327, Accuracy: 38/60(63%)
#
#
# Test set : Average loss:0.7988, Accuracy: 46/60(77%)
#
#
# Test set : Average loss:0.8269, Accuracy: 43/60(72%)
#
#
# Test set : Average loss:0.8848, Accuracy: 47/60(78%)
#
#
# Test set : Average loss:1.0982, Accuracy: 47/60(78%)
#
#
# Test set : Average loss:1.1325, Accuracy: 45/60(75%)
#
#
# Test set : Average loss:1.7966, Accuracy: 38/60(63%)
#
#
# Test set : Average loss:0.8744, Accuracy: 45/60(75%)
#
#
# Test set : Average loss:0.7238, Accuracy: 48/60(80%)
#
#
# Test set : Average loss:0.8731, Accuracy: 47/60(78%)
#
#
# Test set : Average loss:0.8836, Accuracy: 49/60(82%)
#
#
# Test set : Average loss:0.8411, Accuracy: 49/60(82%)
#
#
# Test set : Average loss:0.8822, Accuracy: 47/60(78%)
#
#
# Test set : Average loss:1.2654, Accuracy: 46/60(77%)
#
#
# Test set : Average loss:1.0981, Accuracy: 48/60(80%)
#
#
# Test set : Average loss:1.2352, Accuracy: 48/60(80%)
#
#
# Test set : Average loss:1.4104, Accuracy: 47/60(78%)
#
#
# Test set : Average loss:1.6923, Accuracy: 40/60(67%)
#
#
# Test set : Average loss:1.0994, Accuracy: 38/60(63%)
#
#
# Test set : Average loss:0.6660, Accuracy: 46/60(77%)
#
#
# Test set : Average loss:0.7256, Accuracy: 46/60(77%)
#
#
# Test set : Average loss:0.8060, Accuracy: 41/60(68%)
#
#
# Test set : Average loss:0.6474, Accuracy: 45/60(75%)
#
#
# Test set : Average loss:0.5735, Accuracy: 48/60(80%)
#
#
# Test set : Average loss:0.5950, Accuracy: 49/60(82%)
#
#
# Test set : Average loss:0.6540, Accuracy: 46/60(77%)
#
#
# Test set : Average loss:0.8487, Accuracy: 49/60(82%)
#
#
# Test set : Average loss:0.8302, Accuracy: 47/60(78%)
#
#
# Test set : Average loss:1.0535, Accuracy: 46/60(77%)
#
#
# Test set : Average loss:1.0445, Accuracy: 48/60(80%)
#
#
# Test set : Average loss:1.3395, Accuracy: 48/60(80%)
#
#
# Test set : Average loss:1.2945, Accuracy: 48/60(80%)
#
#
# Test set : Average loss:1.4898, Accuracy: 47/60(78%)
#
#
# Test set : Average loss:1.6411, Accuracy: 48/60(80%)
#
#
# Test set : Average loss:1.7526, Accuracy: 48/60(80%)
#
#
# Test set : Average loss:1.9803, Accuracy: 47/60(78%)
#
#
# Test set : Average loss:1.9738, Accuracy: 46/60(77%)
#
#
# Test set : Average loss:2.2932, Accuracy: 49/60(82%)
#
#
# Test set : Average loss:2.1994, Accuracy: 46/60(77%)
#
#
# Test set : Average loss:2.2174, Accuracy: 48/60(80%)
#
#
# Test set : Average loss:2.2091, Accuracy: 49/60(82%)
#
#
# Test set : Average loss:2.0801, Accuracy: 48/60(80%)
#
#
# Test set : Average loss:2.1411, Accuracy: 50/60(83%)
#
#
# Test set : Average loss:2.0311, Accuracy: 39/60(65%)
#
#
# Test set : Average loss:1.5338, Accuracy: 39/60(65%)
#
#
# Test set : Average loss:0.6017, Accuracy: 47/60(78%)
#
#
# Test set : Average loss:0.8985, Accuracy: 39/60(65%)
#
#
# Test set : Average loss:0.6494, Accuracy: 45/60(75%)
#
#
# Test set : Average loss:0.6199, Accuracy: 47/60(78%)
#
#
# Test set : Average loss:0.6621, Accuracy: 50/60(83%)
#
#
# Test set : Average loss:0.7618, Accuracy: 48/60(80%)
#
#
# Test set : Average loss:0.7543, Accuracy: 49/60(82%)
#
#
# Test set : Average loss:0.8040, Accuracy: 50/60(83%)
#
#
# Test set : Average loss:0.8884, Accuracy: 49/60(82%)
#
#
# Test set : Average loss:1.0220, Accuracy: 49/60(82%)
#
#
# Test set : Average loss:1.1606, Accuracy: 49/60(82%)
#
#
# Test set : Average loss:1.2661, Accuracy: 49/60(82%)
#
#
# Test set : Average loss:1.3883, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:1.5126, Accuracy: 50/60(83%)
#
#
# Test set : Average loss:1.6261, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:1.7326, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:1.8373, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:1.9527, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:2.0613, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:2.1674, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:2.2680, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:2.3578, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:2.4367, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:2.5083, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:2.5768, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:2.6371, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:2.6890, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:2.7421, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:2.7866, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:2.8278, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:2.8667, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:2.9004, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:2.9350, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:2.9673, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:2.9985, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:3.0285, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:3.0583, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:3.0849, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:3.1117, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:3.1355, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:3.1593, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:3.1830, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:3.2037, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:3.2272, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:3.2498, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:3.2716, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:3.2919, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:3.3164, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:3.3395, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:3.3601, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:3.3803, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:3.3995, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:3.4172, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:3.4363, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:3.4544, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:3.4707, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:3.4877, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:3.5057, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:3.5233, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:3.5404, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:3.5589, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:3.5766, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:3.5942, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:3.6110, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:3.6265, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:3.6444, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:3.6622, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:3.6811, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:3.7001, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:3.7175, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:3.7332, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:3.7511, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:3.7680, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:3.7831, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:3.7975, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:3.8118, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:3.8260, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:3.8410, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:3.8563, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:3.8730, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:3.8876, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:3.9010, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:3.9137, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:3.9272, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:3.9404, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:3.9536, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:3.9670, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:3.9799, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:3.9928, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:4.0061, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:4.0196, Accuracy: 51/60(85%)
#
#
# Test set : Average loss:4.0309, Accuracy: 51/60(85%)
